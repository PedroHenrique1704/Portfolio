# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
sinasc_raw = pd.read_csv('SINASC_RO_2019.csv')
sinasc_raw.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
#        'munResUf', 'munResLat', 'munResLon', 'munResAlt', 'munResArea'],
#       dtype='object')

# %% [markdown]
# # Exercicios

# %% [markdown]
# ### 1. Crie 2 faixas de Latitude do município (munResLat) sendo uma acima e outra abaixo de -10.5 e aplique o groupby usando essas faixas como chave e realize operações de soma, media, minimo, maximo, mediana, desvio padrao, variancia pra pelo menos 2 variáveis numéricas ainda não utilizadas

# %%
sinasc_lat = sinasc_raw

def faixa_latitude(munResLat):
    if munResLat > -10.5:
        return 'Acima de -10.5'
    else:
        return 'Abaixo de -10.5'

sinasc_lat['munResLat'] = sinasc_raw['munResLat'].apply(faixa_latitude)

# %%
sinasc_lat.groupby('munResLat').agg({
    'IDADEMAE': ['sum', 'mean', 'min', 'max', 'median', 'std', 'var'],
    'IDADEPAI': ['sum', 'mean', 'min', 'max', 'median', 'std', 'var']
})
# Out:
#                 IDADEMAE                                                 \
#                      sum       mean min max median       std        var
# munResLat
# Abaixo de -10.5   340167  26.178775  12  53   26.0  6.320171  39.944563
# Acima de -10.5    365094  26.014964  11  52   25.0  6.447663  41.572355
#
#                         IDADEPAI                                          \
#                  count       sum       mean   min   max median       std
# munResLat
# Abaixo de -10.5  12994  198482.0  30.901759  15.0  86.0   30.0  7.707202
# Acima de -10.5   14034   38038.0  32.126689  16.0  73.0   31.0  8.034214
#
#
#                        var count
# munResLat
# Abaixo de -10.5  59.400967  6423
# Acima de -10.5   64.548602  1184

# %% [markdown]
# ### 2. Crie 2 faixas da área dos municípios (munResArea) sendo uma acima e outra abaixo de 3000 e aplique o groupby usando essas faixas como chave e realize operações de soma, media, minimo, maximo, mediana, desvio padrao, variancia pra pelo menos 2 variáveis numéricas ainda não utilizadas

# %%
sinasc_area = sinasc_raw

def faixa_area(munResArea):
    if munResArea > 3000:
        return 'Acima de 3000'
    else:
        return 'Abaixo de 3000'

sinasc_area['munResArea'] = sinasc_raw['munResArea'].apply(faixa_area)

# %%
sinasc_area.groupby('munResArea').agg({
    'QTDFILVIVO': ['sum', 'mean', 'min', 'max', 'median', 'std', 'var'],
    'QTDFILMORT': ['sum', 'mean', 'min', 'max', 'median', 'std', 'var']
})
# Out:
#                QTDFILVIVO                                                  \
#                       sum      mean  min   max median       std       var
# munResArea
# Abaixo de 3000     4774.0  0.924298  0.0  30.0    1.0  1.075338  1.156352
# Acima de 3000     22053.0  1.086890  0.0  14.0    1.0  1.191750  1.420268
#
#                       QTDFILMORT                                        \
#                 count        sum      mean  min   max median       std
# munResArea
# Abaixo de 3000   5165     1261.0  0.244949  0.0   4.0    0.0  0.551262
# Acima de 3000   20290     5383.0  0.272116  0.0  28.0    0.0  0.629081
#
#
#                      var  count
# munResArea
# Abaixo de 3000  0.303889   5148
# Acima de 3000   0.395743  19782

# %% [markdown]
# ### 3. Determine faixas na variável munResAlt e aplique o groupby usando essas faixas como chave e realize operações de soma, media, minimo, maximo, mediana, desvio padrao, variancia pra pelo menos 2 variáveis numéricas ainda não utilizadas

# %%
sinasc_alt = sinasc_raw

def faixa_alt(munResAlt):
    if munResAlt > 300:
        return 'Acima de 300'
    else:
        return 'Abaixo de 300'

sinasc_alt['munResAlt'] = sinasc_raw['munResAlt'].apply(faixa_alt)

# %%
sinasc_alt.groupby('munResAlt').agg({
    'PESO': ['sum', 'mean', 'min', 'max', 'median', 'std', 'var'],
    'APGAR5': ['sum', 'mean', 'min', 'max', 'median', 'std', 'var']
})
# Out:
#                    PESO                                              \
#                     sum         mean  min   max  median         std
# munResAlt
# Abaixo de 300  79600169  3243.558494  285  5985  3270.0  544.179495
# Acima de 300    8056788  3239.560917  258  4980  3280.0  550.489205
#
#                                 APGAR5                                        \
#                          var       sum      mean  min   max median       std
# munResAlt
# Abaixo de 300  296131.323117  224572.0  9.186452  0.0  10.0    9.0  0.797884
# Acima de 300   303038.364650   22577.0  9.107301  0.0  10.0    9.0  0.710653
#
#
#                     var
# munResAlt
# Abaixo de 300  0.636619
# Acima de 300   0.505027

# %% [markdown]
# ### 4. Plote no mesmo grafico ao longo do tempo a idade media das mulheres de cada regiao imediatas de rondonia

# %%
imediatas = {
    "Candeias do Jamari": "Porto Velho",
    "Guajará-Mirim": "Porto Velho",
    "Itapuã do Oeste": "Porto Velho",
    "Nova Mamoré": "Porto Velho",
    "Porto Velho": "Porto Velho",
    "Ariquemes": "Ariquemes",
    "Alto Paraíso": "Ariquemes",
    "Buritis": "Ariquemes",
    "Cacaulândia": "Ariquemes",
    "Campo Novo de Rondônia": "Ariquemes",
    "Cujubim": "Ariquemes",
    "Monte Negro": "Ariquemes",
    "Rio Crespo": "Ariquemes",
    "Jaru": "Jaru",
    "Governador Jorge Teixeira": "Jaru",
    "Machadinho D'Oeste": "Jaru",
    "Theobroma": "Jaru",
    "Vale do Anari": "Jaru",
    "Alvorada D'Oeste": "Ji-Paraná",
    "Costa Marques": "Ji-Paraná",
    "Ji-Paraná": "Ji-Paraná",
    "Mirante da Serra": "Ji-Paraná",
    "Nova União": "Ji-Paraná",
    "Ouro Preto do Oeste": "Ji-Paraná",
    "Presidente Médici": "Ji-Paraná",
    "São Francisco do Guaporé": "Ji-Paraná",
    "São Miguel do Guaporé": "Ji-Paraná",
    "Seringueiras": "Ji-Paraná",
    "Teixeirópolis": "Ji-Paraná",
    "Urupá": "Ji-Paraná",
    "Vale do Paraíso": "Ji-Paraná",
    "Cacoal": "Cacoal",
    "Alta Floresta D'Oeste": "Cacoal",
    "Alto Alegre dos Parecis": "Cacoal",
    "Castanheiras": "Cacoal",
    "Espigão D'Oeste": "Cacoal",
    "Ministro Andreazza": "Cacoal",
    "Nova Brasilândia D'Oeste": "Cacoal",
    "Novo Horizonte do Oeste": "Cacoal",
    "Parecis": "Cacoal",
    "Pimenta Bueno": "Cacoal",
    "Primavera de Rondônia": "Cacoal",
    "Rolim de Moura": "Cacoal",
    "Santa Luzia D'Oeste": "Cacoal",
    "São Felipe D'Oeste": "Cacoal",
    "Vilhena": "Vilhena",
    "Cabixi": "Vilhena",
    "Cerejeiras": "Vilhena",
    "Chupinguaia": "Vilhena",
    "Colorado do Oeste": "Vilhena",
    "Corumbiara": "Vilhena",
    "Pimenteiras do Oeste": "Vilhena"
}

# %%
sinasc_imediatas = sinasc_raw[sinasc_raw['munResNome'].isin(imediatas.values())]
sinasc_imediatas.groupby('munResNome').agg({
    'IDADEMAE': ['mean']
})
# Out:
#               IDADEMAE
#                   mean
# munResNome
# Ariquemes    25.607866
# Cacoal       26.890102
# Jaru         25.982974
# Ji-Paraná    26.361137
# Porto Velho  26.312670
# Vilhena      26.433962

# %% [markdown]
# ### 5. Utilize a tabela do link abaixo e crie faixas utilizando o mapping e gere agrupamentos utilizando essas faixas como chave

# %% [markdown]
# ### 5.1 IDH
# A - https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_IDH-M

# %%
agrupamento_idh = {

    "Porto Velho": "IDH-Alto",
    "Vilhena" : "IDH-Alto",
    "Cacoal" : "IDH-Alto",
    "Ji-Paraná" : "IDH-Alto",
    "Pimenta Bueno": "IDH-Alto",
    "Ariquemes" : "IDH-Alto",
    "Rolim de Moura": "IDH-Alto",

    "Cerejeiras": "IDH-Médio",
    "Jaru": "IDH-Médio",
    "Colorado do Oeste": "IDH-Médio",
    "Ouro Preto do Oeste": "IDH-Médio",
    "Espigão do Oeste": "IDH-Médio",
    "Santa Luzia do Oeste": "IDH-Médio",
    "Pimenteiras do Oeste": "IDH-Médio",
    "Presidente Médici": "IDH-Médio",
    "Castanheiras": "IDH-Médio",
    "Guarajá-Mirim": "IDH-Médio",
    "Chupinguaia": "IDH-Médio",
    "Cabixi": "IDH-Médio",
    "Candeias do Jamari": "IDH-Médio",
    "São Felipe do Oeste": "IDH-Médio",
    "Cacaulândia": "IDH-Médio",
    "São Miguel do Guaporé": "IDH-Médio",
    "Mirante da Serra": "IDH-Médio",
    "alvorada do Oeste": "IDH-Médio",
    "Teixeirópolis": "IDH-Médio",
    "Nova Brasilândia do Oeste": "IDH-Médio",
    "Rio Crespo": "IDH-Médio",
    "Primavera de Rondônia": "IDH-Médio",
    "Alta Floresta do Oeste": "IDH-Médio",
    "Ministro Andreazza": "IDH-Médio",
    "Novo HOrizonte do Oeste": "IDH-Médio",
    "Vale do Paraíso": "IDH-Médio",
    "Alto Paraíso": "IDH-Médio",
    "Parecis": "IDH-Médio",
    "Buritis": "IDH-Médio",
    "Itapuã do Oeste": "IDH-Médio",
    "Corumbiara": "IDH-Médio",
    "Cujubim": "IDH-Médio",
    "Costa Marques": "IDH-Médio",
    "São Franciso do Guaporé": "IDH-Médio",
    "Urupá": "IDH-Médio",
    "Monte Negro": "IDH-Médio",

    "Seringueiras": "IDH-Baixo",
    "Governador Jorge Teixeira": "IDH-Baixo",
    "Machadinho do Oeste": "IDH-Baixo",
    "Campo Novo de Rondônia": "IDH-Baixo",
    "Alto Alegre dos Parecis": "IDH-Baixo",
    "Theobroma": "IDH-Baixo",
    "Nova União": "IDH-Baixo",
    "Nova Mamoré": "IDH-Baixo",
    "Vale do Anari": "IDH-Baixo"

}

# %%
sinasc_munResNome = sinasc_raw.set_index('munResNome')
sinasc_munResNome.groupby(agrupamento_idh).sum()
# Out:
#             ORIGEM      CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# munResNome
# IDH-Alto     16855  5.561136e+10  1876774628    16999    442955    42463.0
# IDH-Baixo     1326  4.329888e+09   145909738     1358     33507     3148.0
# IDH-Médio     5728  1.830926e+10   633369871     5807    148310    14958.0
#
#                                                        ESCMAE    CODOCUPMAE  \
# munResNome
# IDH-Alto    12 anos ou mais12 anos ou mais8 a 11 anos12 an...  1.196786e+10
# IDH-Baixo   12 anos ou mais8 a 11 anos8 a 11 anos4 a 7 ano...  9.418509e+08
# IDH-Médio   12 anos ou mais12 anos ou mais12 anos ou mais8...  4.131805e+09
#
#             QTDFILVIVO  QTDFILMORT  ...  PARIDADE KOTELCHUCK     CONTADOR  \
# munResNome                          ...
# IDH-Alto       16228.0      4201.0  ...     10726      84857  12524115512
# IDH-Baixo       1314.0       306.0  ...       875       6860    975579399
# IDH-Médio       5627.0      1386.0  ...      3736      26958   4121004866
#
#                                                  munResStatus  \
# munResNome
# IDH-Alto    ATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOA...
# IDH-Baixo   ATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOA...
# IDH-Médio   ATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOA...
#
#                                                    munResTipo  \
# munResNome
# IDH-Alto    MUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICM...
# IDH-Baixo   MUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICM...
# IDH-Médio   MUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICM...
#
#                                                      munResUf  \
# munResNome
# IDH-Alto    RondôniaRondôniaRondôniaRondôniaRondôniaRondôn...
# IDH-Baixo   RondôniaRondôniaRondôniaRondôniaRondôniaRondôn...
# IDH-Médio   RondôniaRondôniaRondôniaRondôniaRondôniaRondôn...
#
#                                                     munResLat     munResLon  \
# munResNome
# IDH-Alto    Abaixo de -10.5Acima de -10.5Acima de -10.5Aci... -1.057702e+06
# IDH-Baixo   Abaixo de -10.5Abaixo de -10.5Abaixo de -10.5A... -8.426241e+04
# IDH-Médio   Acima de -10.5Acima de -10.5Acima de -10.5Acim... -3.580797e+05
#
#                                                     munResAlt  \
# munResNome
# IDH-Alto    Abaixo de 300Abaixo de 300Abaixo de 300Abaixo ...
# IDH-Baixo   Acima de 300Acima de 300Acima de 300Acima de 3...
# IDH-Médio   Abaixo de 300Abaixo de 300Abaixo de 300Abaixo ...
#
#                                                    munResArea
# munResNome
# IDH-Alto    Abaixo de 3000Acima de 3000Acima de 3000Acima ...
# IDH-Baixo   Acima de 3000Acima de 3000Acima de 3000Acima d...
# IDH-Médio   Acima de 3000Abaixo de 3000Abaixo de 3000Abaix...
#
# [3 rows x 68 columns]

# %% [markdown]
# ### 5.2 IFDM
# B - https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_IFDM

# %%
agrupamento_ifdm = {

         "Ariquemes":"Desenvolvimento Moderado",
         "Vilhena":"Desenvolvimento Moderado",
         "Pimenta Bueno":"Desenvolvimento Moderado",
         "Porto Velho":"Desenvolvimento Moderado",
         "Ji-Paraná":"Desenvolvimento Moderado",
         "Cacoal":"Desenvolvimento Moderado",
         "Santa Luzia do Oeste":"Desenvolvimento Moderado",
         "Rolim de Moura":"Desenvolvimento Moderado",
         "Chupinguaia":"Desenvolvimento Moderado",
         "São MIguel do Guaporé":"Desenvolvimento Moderado",
         "Pimenteiras do Oeste":"Desenvolvimento Moderado",
         "Teixeirópolis":"Desenvolvimento Moderado",
         "Colorado do Oeste":"Desenvolvimento Moderado",
         "Jaru":"Desenvolvimento Moderado",
         "Rio Crespo":"Desenvolvimento Moderado",
         "Primavera de Rondônia":"Desenvolvimento Moderado",
         "Alta Floresta do Oeste":"Desenvolvimento Moderado",
         "Ouro Preto do Oeste":"Desenvolvimento Moderado",
         "São Franciso do Guaporé":"Desenvolvimento Moderado",
         "Candeiras do Jamari":"Desenvolvimento Moderado",
         "Buritis":"Desenvolvimento Moderado",
         "São Felipe do Oeste":"Desenvolvimento Moderado",
         "Presidente Médici":"Desenvolvimento Moderado",
         "Cerejeiras":"Desenvolvimento Moderado",
         "Monte Negro":"Desenvolvimento Moderado",
         "Urupá":"Desenvolvimento Moderado",

         "Espigão do Oeste":"Desenvolvimento Regular",
         "Seringueiras":"Desenvolvimento Regular",
         "Alvorada do Oeste":"Desenvolvimento Regular",
         "Itapuã do Oeste":"Desenvolvimento Regular",
         "Cabixi":"Desenvolvimento Regular",
         "Novo Horizonte do Oeste":"Desenvolvimento Regular",
         "Nova Brasilândia do Oeste":"Desenvolvimento Regular",
         "Vale do Paraíso":"Desenvolvimento Regular",
         "Corumbiara":"Desenvolvimento Regular",
         "Alto Paraíso":"Desenvolvimento Regular",
         "Cacaulândia":"Desenvolvimento Regular",
         "Vale do Anari":"Desenvolvimento Regular",
         "Ministro Andreazza":"Desenvolvimento Regular",
         "Costa Marques":"Desenvolvimento Regular",
         "Nova União":"Desenvolvimento Regular",
         "Guajará-Mirim":"Desenvolvimento Regular",
         "Mirante da Serra":"Desenvolvimento Regular",
         "Parecis":"Desenvolvimento Regular",
         "Castanheiras":"Desenvolvimento Regular",
         "Theobroma":"Desenvolvimento Regular",
         "Machadino do Oeste":"Desenvolvimento Regular",
         "Campo novo de Rondônia":"Desenvolvimento Regular",
         "Nova Mamoré":"Desenvolvimento Regular",
         "Cujubim":"Desenvolvimento Regular",
         "Alto Alegre dos Parecis":"Desenvolvimento Regular",
         "Governador Jorge Teixeira":"Desenvolvimento Regular",
      }

# %%
sinasc_munResNome.groupby(agrupamento_ifdm).sum()
# Out:
#                           ORIGEM      CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  \
# munResNome
# Desenvolvimento Moderado   20433  6.683946e+10  2273162773    20621    536504
# Desenvolvimento Regular     3499  1.061607e+10   386481915     3585     89014
#
#                           ESTCIVMAE  \
# munResNome
# Desenvolvimento Moderado    51787.0
# Desenvolvimento Regular      7747.0
#
#                                                                      ESCMAE  \
# munResNome
# Desenvolvimento Moderado  12 anos ou mais12 anos ou mais8 a 11 anos12 an...
# Desenvolvimento Regular   12 anos ou mais8 a 11 anos8 a 11 anos8 a 11 an...
#
#                             CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  PARIDADE  \
# munResNome                                                      ...
# Desenvolvimento Moderado  1.446657e+10     19538.0      5067.0  ...     13029
# Desenvolvimento Regular   2.607080e+09      4003.0       881.0  ...      2362
#
#                          KOTELCHUCK     CONTADOR  \
# munResNome
# Desenvolvimento Moderado     101348  15093513216
# Desenvolvimento Regular       18747   2542798942
#
#                                                                munResStatus  \
# munResNome
# Desenvolvimento Moderado  ATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOA...
# Desenvolvimento Regular   ATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOA...
#
#                                                                  munResTipo  \
# munResNome
# Desenvolvimento Moderado  MUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICM...
# Desenvolvimento Regular   MUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICM...
#
#                                                                    munResUf  \
# munResNome
# Desenvolvimento Moderado  RondôniaRondôniaRondôniaRondôniaRondôniaRondôn...
# Desenvolvimento Regular   RondôniaRondôniaRondôniaRondôniaRondôniaRondôn...
#
#                                                                   munResLat  \
# munResNome
# Desenvolvimento Moderado  Abaixo de -10.5Acima de -10.5Acima de -10.5Aci...
# Desenvolvimento Regular   Abaixo de -10.5Abaixo de -10.5Abaixo de -10.5A...
#
#                              munResLon  \
# munResNome
# Desenvolvimento Moderado -1.280709e+06
# Desenvolvimento Regular  -2.222598e+05
#
#                                                                   munResAlt  \
# munResNome
# Desenvolvimento Moderado  Abaixo de 300Abaixo de 300Abaixo de 300Abaixo ...
# Desenvolvimento Regular   Acima de 300Abaixo de 300Acima de 300Acima de ...
#
#                                                                  munResArea
# munResNome
# Desenvolvimento Moderado  Abaixo de 3000Acima de 3000Acima de 3000Acima ...
# Desenvolvimento Regular   Acima de 3000Abaixo de 3000Acima de 3000Acima ...
#
# [2 rows x 68 columns]

# %% [markdown]
# ### 5.3 PIB
# C - https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_PIB

# %%
agrupamento_pib = {

  "Porto Velho":"Acima de 1 Bilhão",
  "Ji-Paraná":"Acima de 1 Bilhão",
  "Vilhena":"Acima de 1 Bilhão",
  "Ariquemes":"Acima de 1 Bilhão",
  "Cacoal":"Acima de 1 Bilhão",
  "Jaru":"Acima de 1 Bilhão",
  "Rolim de Moura":"Acima de 1 Bilhão",
  "Pimenta Bueno":"Acima de 1 Bilhão",

  "Guajará-Mirim":"Acima de 500 Milhões",
  "Ouro Preto do Oeste":"Acima de 500 Milhões",
  "Buritis":"Acima de 500 Milhões",
  "Machadinho do Oeste":"Acima de 500 Milhões",
  "Espigão do Oeste":"Acima de 500 Milhões",
  "São Miguel do Guaporé":"Acima de 500 Milhões",
  "Candeias do Jamari":"Acima de 500 Milhões",
  "Nova Mamoré":"Acima de 500 Milhões",
  "Cerejeiras":"Acima de 500 Milhões",

  "Alta Floresta do Oeste":"Acima de 300 Milhões",
  "Presidente Médici":"Acima de 300 Milhões",
  "Cujubim":"Acima de 300 Milhões",
  "Nova Brasilândia do Oeste":"Acima de 300 Milhões",
  "Alto Paraíso":"Acima de 300 Milhões",
  "São Francisco do Guaporé":"Acima de 300 Milhões",
  "Colorado do Oeste":"Acima de 300 Milhões",

  "Monte Negro":"Acima de 200 Milhões",
  "Alto Alegre dos Parecis":"Acima de 200 Milhões",
  "Campo Novo de Rondônia":"Acima de 200 Milhões",
  "Alvorada do Oeste":"Acima de 200 Milhões",

  "Chupinguaia":"Acima de 100 Milhões",
  "Corumbiara":"Acima de 100 Milhões",
  "Minitro Andreazza":"Acima de 100 Milhões",
  "Urupá":"Acima de 100 Milhões",
  "Costa Marques":"Acima de 100 Milhões",
  "Seringueiras":"Acima de 100 Milhões",
  "Mirante da Serra":"Acima de 100 Milhões",
  "Governador Jorge Teixiera":"Acima de 100 Milhões",
  "Theobroma":"Acima de 100 Milhões",
  "Santa Luzia do Oeste":"Acima de 100 Milhões",
  "Novo horizonte do Oeste":"Acima de 100 Milhões",
  "Itapuã do Oeste":"Acima de 100 Milhões",
  "Vale do Paraíso":"Acima de 100 Milhões",
  "Cacaulândia":"Acima de 100 Milhões",
  "Cabixi":"Acima de 100 Milhões",
  "Vale do Anari":"Acima de 100 Milhões",

  "Nova União":"Até 100 Milhões",
  "Parecis":"Até 100 Milhões",
  "Rio Crespo":"Até 100 Milhões",
  "Pimenteiras do Oeste":"Até 100 Milhões",
  "Teixeirópolis":"Até 100 Milhões",
  "São Felipe do Oeste":"Até 100 Milhões",
  "Castanheiras":"Até 100 Milhões",
  "Primavera de Rondônia":"Até 100 Milhões"

}

# %%
sinasc_munResNome.groupby(agrupamento_pib).sum()
# Out:
#                       ORIGEM      CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  \
# munResNome
# Acima de 1 Bilhão      17736  5.821665e+10  1973696858    17888    465846
# Acima de 100 Milhões    1559  5.154311e+09   172377507     1588     39791
# Acima de 200 Milhões     519  1.774199e+09    57115320      526     13051
# Acima de 300 Milhões    1252  4.602814e+09   138574400     1265     32184
# Acima de 500 Milhões    3354  1.081925e+10   370996838     3441     86486
# Até 100 Milhões          377  1.026801e+09    41699233      379      9998
#
#                       ESTCIVMAE  \
# munResNome
# Acima de 1 Bilhão       44866.0
# Acima de 100 Milhões     4028.0
# Acima de 200 Milhões     1262.0
# Acima de 300 Milhões     3320.0
# Acima de 500 Milhões     7472.0
# Até 100 Milhões           955.0
#
#                                                                  ESCMAE  \
# munResNome
# Acima de 1 Bilhão     12 anos ou mais12 anos ou mais8 a 11 anos12 an...
# Acima de 100 Milhões  8 a 11 anos12 anos ou mais8 a 11 anos12 anos o...
# Acima de 200 Milhões  12 anos ou mais8 a 11 anos8 a 11 anos12 anos o...
# Acima de 300 Milhões  12 anos ou mais12 anos ou mais8 a 11 anos12 an...
# Acima de 500 Milhões  12 anos ou mais8 a 11 anos12 anos ou mais4 a 7...
# Até 100 Milhões       8 a 11 anos4 a 7 anos8 a 11 anos8 a 11 anos8 a...
#
#                         CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  PARIDADE  \
# munResNome                                                  ...
# Acima de 1 Bilhão     1.260803e+10     17007.0      4405.0  ...     11284
# Acima de 100 Milhões  1.073950e+09      1553.0       355.0  ...      1003
# Acima de 200 Milhões  3.922164e+08       480.0       118.0  ...       331
# Acima de 300 Milhões  9.586925e+08      1317.0       310.0  ...       830
# Acima de 500 Milhões  2.453503e+09      3765.0       917.0  ...      2271
# Até 100 Milhões       2.464833e+08       384.0        64.0  ...       247
#
#                      KOTELCHUCK     CONTADOR  \
# munResNome
# Acima de 1 Bilhão         89004  13192168568
# Acima de 100 Milhões       7266   1129745008
# Acima de 200 Milhões       2418    387234229
# Acima de 300 Milhões       5761    909060775
# Acima de 500 Milhões      18085   2352093834
# Até 100 Milhões            1773    265288365
#
#                                                            munResStatus  \
# munResNome
# Acima de 1 Bilhão     ATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOA...
# Acima de 100 Milhões  ATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOA...
# Acima de 200 Milhões  ATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOA...
# Acima de 300 Milhões  ATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOA...
# Acima de 500 Milhões  ATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOA...
# Até 100 Milhões       ATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOATIVOA...
#
#                                                              munResTipo  \
# munResNome
# Acima de 1 Bilhão     MUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICM...
# Acima de 100 Milhões  MUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICM...
# Acima de 200 Milhões  MUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICM...
# Acima de 300 Milhões  MUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICM...
# Acima de 500 Milhões  MUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICM...
# Até 100 Milhões       MUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICMUNICM...
#
#                                                                munResUf  \
# munResNome
# Acima de 1 Bilhão     RondôniaRondôniaRondôniaRondôniaRondôniaRondôn...
# Acima de 100 Milhões  RondôniaRondôniaRondôniaRondôniaRondôniaRondôn...
# Acima de 200 Milhões  RondôniaRondôniaRondôniaRondôniaRondôniaRondôn...
# Acima de 300 Milhões  RondôniaRondôniaRondôniaRondôniaRondôniaRondôn...
# Acima de 500 Milhões  RondôniaRondôniaRondôniaRondôniaRondôniaRondôn...
# Até 100 Milhões       RondôniaRondôniaRondôniaRondôniaRondôniaRondôn...
#
#                                                               munResLat  \
# munResNome
# Acima de 1 Bilhão     Abaixo de -10.5Acima de -10.5Acima de -10.5Aci...
# Acima de 100 Milhões  Acima de -10.5Acima de -10.5Acima de -10.5Acim...
# Acima de 200 Milhões  Abaixo de -10.5Abaixo de -10.5Abaixo de -10.5A...
# Acima de 300 Milhões  Acima de -10.5Acima de -10.5Acima de -10.5Acim...
# Acima de 500 Milhões  Acima de -10.5Acima de -10.5Acima de -10.5Acim...
# Até 100 Milhões       Acima de -10.5Acima de -10.5Acima de -10.5Acim...
#
#                          munResLon  \
# munResNome
# Acima de 1 Bilhão    -1.112744e+06
# Acima de 100 Milhões -9.735483e+04
# Acima de 200 Milhões -3.268294e+04
# Acima de 300 Milhões -7.818138e+04
# Acima de 500 Milhões -2.137607e+05
# Até 100 Milhões      -2.340618e+04
#
#                                                               munResAlt  \
# munResNome
# Acima de 1 Bilhão     Abaixo de 300Abaixo de 300Abaixo de 300Abaixo ...
# Acima de 100 Milhões  Abaixo de 300Abaixo de 300Abaixo de 300Abaixo ...
# Acima de 200 Milhões  Acima de 300Acima de 300Acima de 300Abaixo de ...
# Acima de 300 Milhões  Abaixo de 300Abaixo de 300Abaixo de 300Abaixo ...
# Acima de 500 Milhões  Abaixo de 300Abaixo de 300Abaixo de 300Abaixo ...
# Até 100 Milhões       Abaixo de 300Abaixo de 300Abaixo de 300Abaixo ...
#
#                                                              munResArea
# munResNome
# Acima de 1 Bilhão     Abaixo de 3000Acima de 3000Acima de 3000Acima ...
# Acima de 100 Milhões  Abaixo de 3000Acima de 3000Abaixo de 3000Acima...
# Acima de 200 Milhões  Acima de 3000Acima de 3000Acima de 3000Abaixo ...
# Acima de 300 Milhões  Acima de 3000Abaixo de 3000Abaixo de 3000Acima...
# Acima de 500 Milhões  Acima de 3000Acima de 3000Acima de 3000Acima d...
# Até 100 Milhões       Abaixo de 3000Abaixo de 3000Abaixo de 3000Abai...
#
# [6 rows x 68 columns]

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados.

# %%
sinasc_munResNome.groupby(agrupamento_pib).agg({
    'IDADEMAE': ['mean'],
    'IDADEPAI': ['mean'],
    'QTDFILVIVO': ['mean'],
    'PESO':['mean'],
    'APGAR5':['mean']
})
# Out:
#                        IDADEMAE   IDADEPAI QTDFILVIVO         PESO    APGAR5
#                            mean       mean       mean         mean      mean
# munResNome
# Acima de 1 Bilhão     26.265562  31.108387   1.026435  3247.215719  9.166223
# Acima de 100 Milhões  25.523412  31.455882   1.012386  3257.751764  9.182463
# Acima de 200 Milhões  25.146435  30.187500   1.010526  3233.701349  9.319846
# Acima de 300 Milhões  25.706070  30.819149   1.062097  3240.387380  9.092000
# Acima de 500 Milhões  25.785927  31.381955   1.228385  3243.336315  9.364374
# Até 100 Milhões       26.519894  31.626126   1.032258  3197.679045  9.095491

# %%
sinasc_munResNome.groupby(agrupamento_idh).agg({
    'IDADEMAE': ['mean'],
    'IDADEPAI': ['mean'],
    'QTDFILVIVO': ['mean'],
    'PESO':['mean'],
    'APGAR5':['mean']


})
# Out:
#              IDADEMAE          IDADEPAI       QTDFILVIVO         PESO  \
#                  mean  count       mean count       mean         mean
# munResNome
# IDH-Alto    26.280332  16855  31.074091  4508   1.033960  3245.623791
# IDH-Baixo   25.269231   1326  30.402332   343   1.056270  3244.309955
# IDH-Médio   25.892109   5728  31.579211  1597   1.034755  3236.580656
#
#               APGAR5
#                 mean
# munResNome
# IDH-Alto    9.171668
# IDH-Baixo   9.267925
# IDH-Médio   9.231564

# %%
sinasc_munResNome.groupby(agrupamento_ifdm).agg({
    'IDADEMAE': ['mean'],
    'IDADEPAI': ['mean'],
    'QTDFILVIVO': ['mean'],
    'PESO':['mean'],
    'APGAR5':['mean']
})
# Out:
#                            IDADEMAE   IDADEPAI QTDFILVIVO         PESO  \
#                                mean       mean       mean         mean
# munResNome
# Desenvolvimento Moderado  26.256742  31.124424   1.025724  3243.457887
# Desenvolvimento Regular   25.439840  31.377892   1.172868  3256.320949
#
#                             APGAR5
#                               mean
# munResNome
# Desenvolvimento Moderado  9.182662
# Desenvolvimento Regular   9.220563

# %%
print(sinasc_munResNome.groupby(agrupamento_idh).agg({
    'IDADEMAE': ['mean','count'],
    'IDADEPAI': ['mean','count'], }))

print(sinasc_munResNome.groupby(agrupamento_pib).agg({
    'IDADEMAE': ['mean','count'],
    'IDADEPAI': ['mean','count'], }))

print(sinasc_munResNome.groupby(agrupamento_ifdm).agg({
    'IDADEMAE': ['mean','count'],
    'IDADEPAI': ['mean','count'], }))
# Out:
#              IDADEMAE          IDADEPAI
#                  mean  count       mean count
# munResNome
# IDH-Alto    26.280332  16855  31.074091  4508
# IDH-Baixo   25.269231   1326  30.402332   343
# IDH-Médio   25.892109   5728  31.579211  1597
#                        IDADEMAE          IDADEPAI
#                            mean  count       mean count
# munResNome
# Acima de 1 Bilhão     26.265562  17736  31.108387  4650
# Acima de 100 Milhões  25.523412   1559  31.455882   408
# Acima de 200 Milhões  25.146435    519  30.187500   192
# Acima de 300 Milhões  25.706070   1252  30.819149   282
# Acima de 500 Milhões  25.785927   3354  31.381955   665
# Até 100 Milhões       26.519894    377  31.626126   222
#                            IDADEMAE          IDADEPAI
#                                mean  count       mean count
# munResNome
# Desenvolvimento Moderado  26.256742  20433  31.124424  5642
# Desenvolvimento Regular   25.439840   3499  31.377892   778

# %% [markdown]
# **Insights**
#
#
#
# 1.   PIB, ifdm e IDH não se apresentam como valores de grande impacto, dado que mesmo comparando informações como idade da mãe, do pai, quantidade de filhos e a relação com APGAR5 ambos mostram numeros muito semelhantes.
# 2.   Porem, é visivel que a maioria das mães e pais moram em locais com condições melhores, maior IDH, PIB e  ifdm.
