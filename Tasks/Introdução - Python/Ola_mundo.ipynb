# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo 01** | Python: Variáveis & Tipos de Dados
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Introdução ao Google Colab;</li>
#   <li>Variáveis;</li>
#   <li>Números;</li>
#   <li><i>Strings;</i></li>
#   <li>Boleanos.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# # Nova seção

# %% [markdown]
# ## 1\. Google Colab

# %% [markdown]
# Crie uma célula de código que escreva o texto "Olá mundo!", utilize o comando `print`.

# %%
print("Olá mundo!")
# Out:
# Olá mundo!

# %% [markdown]
# Crie uma célua de texto e adicione uma imagem.

# %%
import cv2
from matplotlib import pyplot as plt
imagem_cobra = cv2.imread('snake.jpg',1)
plt.imshow(cv2.cvtColor(imagem_cobra, cv2.COLOR_BGR2RGB)) ##ajuste de cor
plt.axis("off")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Números

# %% [markdown]
# Preencha as células de código para preencher os valores de (A), (B) e (C) na tabela de ticket médio abaixo:
#
# <br>
#
# | Dia   | Valor Total Vendas | Qtd Total Vendas | Ticket Medio |
# |-------|--------------------|------------------|--------------|
# | 19/01 | (A)                | 3                | 320.52       |
# | 20/01 | 834.47             | (B)              | 119.21       |
# | 23/01 | 15378.12           | 5                | (C)          |

# %%
# (A) Dia 19/01
vtv19 = 320.52 * 3
print("Valor total de vendas do dia 19: R$",vtv19)
# Out:
# Valor total de vendas do dia 19: R$ 961.56

# %%
# (B) Dia 20/01
qtv = 834.47/ 119.21
print("Quantidade total de vendas do dia 20:",int(qtv),"vendas")
# Out:
# Quantidade total de vendas do dia 20: 7 vendas

# %%
# (C) Dia 23/01
tm = 15378.12/5
print("Valor médio do ticket no dia 23: R$",tm)
# Out:
# Valor médio do ticket no dia 23: R$ 3075.6240000000003

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Strings

# %% [markdown]
# Aplique três métodos distintos na *string* abaixo, você pode conferir alguns métodos neste [link](https://www.w3schools.com/python/python_ref_string.asp):

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'
print(cancao.upper())
print(cancao.replace("roda","rd"))
print(cancao.split())
# Out:
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.
# Roda mundo, rd gigante, rd moinho, rd pião.
# ['Roda', 'mundo,', 'roda', 'gigante,', 'roda', 'moinho,', 'roda', 'pião.']

# %% [markdown]
# Extraia da string abaixo o valor da taxa **selic** na variável `selic` e o valor do **ano** na variavel `ano`. Imprima os valores na tela.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'

selic = (noticia[12:17])
print ((selic))

ano = (noticia[-7])
print (ano)
# Out:
# 2,75%
# 6

# %% [markdown]
# ---

# %% [markdown]
# ## 4\. Booleanos

# %% [markdown]
# Utilize a tabela da verdade para responder: qual o valor da variável x?

# %%
a = False
b = True

x = not a & b
### Valor de X = True por conta do "not" fazendo "a" virar True também.
print(x)
# Out:
# True
