# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui

URL = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado"

response = requests.get(URL)
response.json()

datajson = response.json()

df = pd.DataFrame(datajson["items"])

df.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0      10562           Estado  Rio de Janeiro        33  RJ    None
# 1      13560           Estado  Rio de Janeiro        33  RJ    None
# 2      12375           Estado  Rio de Janeiro        33  RJ    None
# 3      13364           Estado  Rio de Janeiro        33  RJ    None
# 4      12410           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.001228/2013-92
# 1                                           Deferido  19405.000026/2002-01
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.001671/2011-00
# 3  Encaminhado à PGFN com manifestação técnica fa...  17944.002059/2008-41
# 4  Encaminhado à PGFN com manifestação técnica fa...  17944.001680/2011-92
#
#          data_protocolo                                      tipo_operacao  \
# ...

# %%
# 2) Seu código aqui #No enunciado pede os 3 que mais se repetem, caso contrario não teria posto o .head(3)
# df.value_counts("status")
df.value_counts("status").head(3)
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Name: count, dtype: int64

# %%
# 3.1) - Observação
print(df['data_status'])
# Out:
# 0     27/12/2013
# 1     27/06/2002
# 2     27/12/2011
# 3     22/05/2009
# 4     10/07/2012
# 5     04/11/2009
# 6     25/10/2016
# 7     01/09/2014
# 8     01/09/2014
# 9     21/11/2013
# 10    06/05/2013
# 11    29/07/2013
# 12    29/05/2012
# 13    04/07/2011
# 14    06/07/2010
# 15    07/06/2011
# 16    16/05/2016
# 17    04/10/2012
# 18    06/08/2009
# 19    27/06/2002
# 20    01/03/2006
# 21    04/07/2014
# 22    19/08/2010
# 23    24/07/2009
# 24    20/04/2010
# 25    06/05/2013
# 26    20/11/2012
# 27    04/07/2011
# 28    04/07/2011
# 29    25/11/2009
# 30    13/07/2006
# 31    26/02/2016
# 32    28/09/2009
# 33    03/09/2012
# 34    28/08/2012
# 35    04/07/2011
# 36    27/06/2002
# 37    14/05/2012
# 38    04/10/2012
# 39    10/07/2012
# 40    01/04/2013
# 41    05/02/2014
# 42    09/12/2009
# 43    28/03/2013
# 44    18/06/2009
# 45    06/03/2008
# 46    14/09/2012
# 47    27/06/2002
# 48    02/07/2012
# 49    07/07/2009
# 50    11/03/2016
# 51    18/04/2008
# ...

# %%
# 3.2) Seu código aqui - tratamento de código

df['data_status'] = df['data_status'].astype(str)

df['ano_status'] = df['data_status'].str.slice(-4,)

print(df[['data_status', 'ano_status']])
# Out:
#    data_status ano_status
# 0   27/12/2013       2013
# 1   27/06/2002       2002
# 2   27/12/2011       2011
# 3   22/05/2009       2009
# 4   10/07/2012       2012
# 5   04/11/2009       2009
# 6   25/10/2016       2016
# 7   01/09/2014       2014
# 8   01/09/2014       2014
# 9   21/11/2013       2013
# 10  06/05/2013       2013
# 11  29/07/2013       2013
# 12  29/05/2012       2012
# 13  04/07/2011       2011
# 14  06/07/2010       2010
# 15  07/06/2011       2011
# 16  16/05/2016       2016
# 17  04/10/2012       2012
# 18  06/08/2009       2009
# 19  27/06/2002       2002
# 20  01/03/2006       2006
# 21  04/07/2014       2014
# 22  19/08/2010       2010
# 23  24/07/2009       2009
# 24  20/04/2010       2010
# 25  06/05/2013       2013
# 26  20/11/2012       2012
# 27  04/07/2011       2011
# 28  04/07/2011       2011
# 29  25/11/2009       2009
# 30  13/07/2006       2006
# 31  26/02/2016       2016
# 32  28/09/2009       2009
# 33  03/09/2012       2012
# ...

# %%
# 4) - Apresentação
df.value_counts("ano_status")
# Out:
# ano_status
# 2012    11
# 2009     9
# 2013     7
# 2011     6
# 2002     4
# 2014     4
# 2016     4
# 2010     3
# 2006     2
# 2008     2
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
# 1) Seu código aqui


def consulta_api(uf, tipo_interessado):
    URL = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl"
    params = {
        "uf": uf,
        "tipo_interessado": tipo_interessado
    }

    response = requests.get(URL, params=params)
    if response.status_code == 200:
        data = response.json()
        df = pd.DataFrame(data["items"])
        return df
    else:
        print("Erro na consulta à API")
        return None

# %%
# 1.1) Teste
df_mg = consulta_api("MG", "Estado")
df_mg.head()
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf num_pvl  \
# 0      11132           Estado  Minas Gerais        31  MG    None
# 1      13602           Estado  Minas Gerais        31  MG    None
# 2      13275           Estado  Minas Gerais        31  MG    None
# 3      11571           Estado  Minas Gerais        31  MG    None
# 4      10011           Estado  Minas Gerais        31  MG    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.001368/2009-84
# 1  Encaminhado à PGFN com manifestação técnica fa...  19405.000034/2005-92
# 2                                 Arquivado a pedido  17944.002000/2013-10
# 3  Encaminhado à PGFN com manifestação técnica fa...  17944.001479/2009-91
# 4                                           Deferido  17944.001099/2010-90
#
#          data_protocolo                                      tipo_operacao  \
# ...

# %%
# 2) Seu código aqui

df_mg = consulta_api("MG", "Estado")
df_mg.head()

solicitacoes_arquivadas_mg = df_mg[df_mg['status'] == 'Arquivado por decurso de prazo']
quantidade_arquivadas_mg = solicitacoes_arquivadas_mg.shape[0]

print(f"Quantidade de solicitações para Minas Gerais com status 'Arquivado por decurso de prazo': {quantidade_arquivadas_mg}")
# Out:
# Quantidade de solicitações para Minas Gerais com status 'Arquivado por decurso de prazo': 1

# %%
# 3) Seu código aqui

df_ba = consulta_api("BA", "Município")

solicitacoes_deferidas_ba = df_ba[df_ba['status'] == 'Deferido']
print(solicitacoes_deferidas_ba['interessado'].value_counts().head(1))
# Out:
# interessado
# Luís Eduardo Magalhães    16
# Name: count, dtype: int64

# %%
# 4) Seu código aqui
df_ba = consulta_api("BA", "Município")

df_ba.to_csv("Solicitacoes_ba_Python.csv", index=False)

# %%
# 4.2) Teste (google collab)
from google.colab import files
df_ba.to_csv('Solicitacoes_ba_Colab.csv')
files.download('Solicitacoes_ba_Colab.csv')
